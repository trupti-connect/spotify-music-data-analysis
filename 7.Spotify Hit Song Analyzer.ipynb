# %% [markdown]
# ## 🎵Spotify Hit Song Analyzer: Predicting Hit Songs and Discovering Music Trends:

# %% [markdown]
# ## Problem Statement:

# %% [markdown]
# * Spotify has millions of songs, but not every song becomes successful. Music labels and streaming platforms need to understand the characteristics of hit songs to make better decisions about marketing, playlist creation, and artist promotion.

# %% [markdown]
# ## Business Objective :

# %% [markdown]
# * Analyze Spotify music trends.
# * Identify factors that influence song popularity.
# * Predict whether a song will become a hit.
# * Group songs into listening moods.
# * Provide business recommendations.

# %% [markdown]
# ## Data Understanding

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\TRUPTI\Downloads\dataset.csv.zip")

# %%
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# * #### Displaying the First Five Rows

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                 artists  \
# 0           0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1           1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2           2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3           3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4           4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           album_name  \
# 0                                             Comedy
# 1                                   Ghost (Acoustic)
# 2                                     To Begin Again
# 3  Crazy Rich Asians (Original Motion Picture Sou...
# 4                                            Hold On
#
#                    track_name  popularity  duration_ms  explicit  \
# 0                      Comedy          73       230666     False
# 1            Ghost - Acoustic          55       149610     False
# 2              To Begin Again          57       210826     False
# ...

# %% [markdown]
# * #### Finding the number of rows and columns

# %%
df.shape
# Out:
# (114000, 21)

# %% [markdown]
# * #### Displaying Column Names

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'track_id', 'artists', 'album_name', 'track_name',
#        'popularity', 'duration_ms', 'explicit', 'danceability', 'energy',
#        'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'time_signature',
#        'track_genre'],
#       dtype='object')

# %% [markdown]
# * #### Understanding the Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %% [markdown]
# * #### Generating Statistical Summary of the Dataset

# %%
df.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %% [markdown]
# * #### Checking for Missing Values

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# * #### Checking for Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# * #### Finding the Number of Unique Values

# %%
df.nunique()
# Out:
# Unnamed: 0          114000
# track_id             89741
# artists              31437
# album_name           46589
# track_name           73608
# popularity             101
# duration_ms          50697
# explicit                 2
# danceability          1174
# energy                2083
# key                     12
# loudness             19480
# mode                     2
# speechiness           1489
# acousticness          5061
# instrumentalness      5346
# liveness              1722
# valence               1790
# tempo                45653
# time_signature           5
# track_genre            114
# dtype: int64

# %% [markdown]
# ## Business Questions

# %% [markdown]
# * #### Number of Songs

# %%
df.shape[0]
# Out:
# 114000

# %% [markdown]
# * #### Number of Artists

# %%
df['artists'].nunique()
# Out:
# 31437

# %% [markdown]
# * #### Number of Albums

# %%
df['album_name'].nunique()
# Out:
# 46589

# %% [markdown]
# * #### Number of Genres

# %%
df['track_genre'].nunique()
# Out:
# 114

# %% [markdown]
# * #### Average Song Duration

# %%
df['duration_ms'].mean() / 60000
# Out:
# np.float64(3.8004858852339183)

# %% [markdown]
# * #### Average Song Duration

# %%
df['popularity'].mean()
# Out:
# np.float64(33.2385350877193)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# * #### Creating a Copy of the Dataset

# %%
spotify = df.copy()

# %% [markdown]
# * #### Check Missing Values

# %%
spotify.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# * #### Display Missing Records

# %%
spotify[spotify.isnull().any(axis=1)]
# Out:
#        Unnamed: 0                track_id artists album_name track_name  \
# 65900       65900  1kR4gIb7nGxHPI3D2ifs59     NaN        NaN        NaN
#
#        popularity  duration_ms  explicit  danceability  energy  ...  loudness  \
# 65900           0            0     False         0.501   0.583  ...     -9.46
#
#        mode  speechiness  acousticness  instrumentalness  liveness  valence  \
# 65900     0       0.0605          0.69           0.00396    0.0747    0.734
#
#          tempo  time_signature  track_genre
# 65900  138.391               4        k-pop
#
# [1 rows x 21 columns]

# %% [markdown]
# * #### Handle Missing Values

# %%
spotify.isnull().sum()
# Out:
# Unnamed: 0          0
# track_id            0
# artists             1
# album_name          1
# track_name          1
# popularity          0
# duration_ms         0
# explicit            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# time_signature      0
# track_genre         0
# dtype: int64

# %% [markdown]
# * #### Check Duplicate Records

# %%
spotify.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# * #### Check Data Types

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %% [markdown]
# * #### Check Unique Values

# %%
spotify.nunique()
# Out:
# Unnamed: 0          114000
# track_id             89741
# artists              31437
# album_name           46589
# track_name           73608
# popularity             101
# duration_ms          50697
# explicit                 2
# danceability          1174
# energy                2083
# key                     12
# loudness             19480
# mode                     2
# speechiness           1489
# acousticness          5061
# instrumentalness      5346
# liveness              1722
# valence               1790
# tempo                45653
# time_signature           5
# track_genre            114
# dtype: int64

# %% [markdown]
# * #### Verify the Cleaned Dataset

# %%
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 21 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Unnamed: 0        114000 non-null  int64
#  1   track_id          114000 non-null  object
#  2   artists           113999 non-null  object
#  3   album_name        113999 non-null  object
#  4   track_name        113999 non-null  object
#  5   popularity        114000 non-null  int64
#  6   duration_ms       114000 non-null  int64
#  7   explicit          114000 non-null  bool
#  8   danceability      114000 non-null  float64
#  9   energy            114000 non-null  float64
#  10  key               114000 non-null  int64
#  11  loudness          114000 non-null  float64
#  12  mode              114000 non-null  int64
#  13  speechiness       114000 non-null  float64
#  14  acousticness      114000 non-null  float64
#  15  instrumentalness  114000 non-null  float64
# ...

# %%
spotify.describe()
# Out:
#           Unnamed: 0     popularity   duration_ms   danceability  \
# count  114000.000000  114000.000000  1.140000e+05  114000.000000
# mean    56999.500000      33.238535  2.280292e+05       0.566800
# std     32909.109681      22.305078  1.072977e+05       0.173542
# min         0.000000       0.000000  0.000000e+00       0.000000
# 25%     28499.750000      17.000000  1.740660e+05       0.456000
# 50%     56999.500000      35.000000  2.129060e+05       0.580000
# 75%     85499.250000      50.000000  2.615060e+05       0.695000
# max    113999.000000     100.000000  5.237295e+06       0.985000
#
#               energy            key       loudness           mode  \
# count  114000.000000  114000.000000  114000.000000  114000.000000
# mean        0.641383       5.309140      -8.258960       0.637553
# std         0.251529       3.559987       5.029337       0.480709
# min         0.000000       0.000000     -49.531000       0.000000
# ...

# %%
spotify.shape
# Out:
# (114000, 21)

# %% [markdown]
# * #### Save the Cleaned Dataset

# %%
spotify.to_csv("spotify_cleaned.csv", index=False)

# %%
df
# Out:
#         Unnamed: 0                track_id                 artists  \
# 0                0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1                1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2                2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3                3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4                4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
# ...            ...                     ...                     ...
# 113995      113995  2C3TZjDRiAzdyViavDJ217           Rainy Lullaby
# 113996      113996  1hIz5L4IB9hN3WRYPOCGPw           Rainy Lullaby
# 113997      113997  6x8ZfSoqDjuNa5SVP5QjvX           Cesária Evora
# 113998      113998  2e6sXL2bYv4bSz6VTdnfLs        Michael W. Smith
# 113999      113999  2hETkH7cOfqmz3LqZDHZf5           Cesária Evora
#
#                                                album_name  \
# 0                                                  Comedy
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# * #### import the required libraries:

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')

# %% [markdown]
# ## Histogram

# %% [markdown]
# * ### Popularity Distribution

# %%
plt.figure(figsize=(8,6))

sns.histplot(
    spotify['popularity'],
    bins=30,
    kde=True,
    color='green',          # Histogram color
    line_kws={'color': 'black', 'linewidth': 2}  # KDE line color
)

plt.title("Popularity Distribution", color='black', fontsize=14, fontweight='bold')
plt.xlabel("Popularity", color='black')
plt.ylabel("Count", color='black')

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# * ### Top 10 Artists by Number of Songs

# %%
top_artist_count = spotify['artists'].value_counts().head(10)

plt.figure(figsize=(10,6))
sns.barplot(
    x=top_artist_count.values,
    y=top_artist_count.index,
    color='green'    # Spotify green
)

plt.title("Top 10 Artists by Number of Songs", color='black')
plt.xlabel("Number of Songs", color='black')
plt.ylabel("Artists", color='black')

plt.xticks(color='black')
plt.yticks(color='black')

plt.show()

# %% [markdown]
# ## Pie Chart

# %% [markdown]
# * ### Explicit vs Non-Explicit Songs

# %%
explicit_count = spotify['explicit'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(
    explicit_count,
    labels=explicit_count.index,
    autopct='%1.1f%%',
    colors=['green', 'black'],   # Green and Black
    textprops={'color': 'white'} # Makes labels visible on black slice
)

plt.title("Explicit vs Non-Explicit Songs", color='black')
plt.show()

# %% [markdown]
# ## Box Plot

# %% [markdown]
# * ### Popularity by Genre

# %%
top10 = spotify['track_genre'].value_counts().head(10).index

plt.figure(figsize=(12,6))

sns.boxplot(
    data=spotify[spotify['track_genre'].isin(top10)],
    x='track_genre',
    y='popularity',
    color='green'   # Spotify green
)

plt.xticks(rotation=45, color='black')
plt.title("Popularity by Genre", color='black')
plt.xlabel("Track Genre", color='black')
plt.ylabel("Popularity", color='black')

plt.show()

# %% [markdown]
# ## Correlation Heatmap

# %%
plt.figure(figsize=(12,8))

corr = spotify.select_dtypes(include='number').corr()

sns.heatmap(
    corr,
    annot=True,
    cmap='Greens',      # Green color palette
    linewidths=0.5,
    linecolor='black'   # Black grid lines
)

plt.title("Correlation Matrix", color='black')
plt.xticks(color='black')
plt.yticks(color='black')

plt.show()

# %% [markdown]
# ## Scatter Plot

# %%
plt.figure(figsize=(8,6))

sns.scatterplot(
    data=spotify,
    x='energy',
    y='popularity',
    alpha=0.5,
    color='green'   # Spotify green
)

plt.title("Energy vs Popularity", color='black')
plt.xlabel("Energy", color='black')
plt.ylabel("Popularity", color='black')

plt.xticks(color='black')
plt.yticks(color='black')

plt.show()

# %% [markdown]
# ## Pair Plot

# %%
features = ['danceability',
            'energy',
            'valence',
            'tempo',
            'popularity']

sns.pairplot(
    spotify[features],
    plot_kws={'color': 'green'},          # Scatter plots in green
    diag_kws={'color': 'green'}           # Histograms in green
)

plt.show()

# %% [markdown]
# ## Business Insights

# %% [markdown]
# * Popular genres receive higher average popularity scores.
# * Danceability and energy positively influence song popularity.
# * Top artists consistently release highly popular tracks.
# * Mood-based clustering groups songs into meaningful listening categories.
# * The machine learning model can predict potential hit songs based on audio features.

# %% [markdown]
# ## Business Recommendations

# %% [markdown]
# * Focus marketing on high-performing genres and artists.
# * Use mood-based playlists to improve user engagement.
# * Apply predictive analytics to identify potential hit songs before release.
# * Optimize recommendation systems using audio features.
# * Support emerging artists based on prediction results.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# This project analyzed Spotify songs to identify the factors that influence music popularity. Using data analysis, visualization, clustering, and machine learning, it provided insights into music trends and predicted hit songs. The findings can help streaming platforms and music labels make data-driven decisions to improve recommendations, marketing strategies, and user engagement.
